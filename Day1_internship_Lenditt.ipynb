# %%
from sklearn.datasets import fetch_california_housing

# %%
import pandas as pad
import numpy as np

# %%
housing=fetch_california_housing()

# %%
df1=pd.DataFrame(housing["data"], columns=housing['feature_names'])
df1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df2=pd.DataFrame(housing["target"], columns=housing['target_names'])
df2
# Out:
#        MedHouseVal
# 0            4.526
# 1            3.585
# 2            3.521
# 3            3.413
# 4            3.422
# ...            ...
# 20635        0.781
# 20636        0.771
# 20637        0.923
# 20638        0.847
# 20639        0.894
#
# [20640 rows x 1 columns]

# %%
df3=pd.concat([df1,df2],axis=1)
df3
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df3.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
df3.shape
# Out:
# (20640, 9)

# %%
# df3["AveBedrms"]=df3["AveBedrms"].astype(str)

# %%
import warnings 
warnings.filterwarnings('ignore')
string_counts_per_column = df3.applymap(lambda x: isinstance(x, str)).sum()

print(string_counts_per_column)
# Out:
# MedInc             0
# HouseAge           0
# AveRooms           0
# AveBedrms      20640
# Population         0
# AveOccup           0
# Latitude           0
# Longitude          0
# MedHouseVal        0
# dtype: int64

# %%
df3.to_csv("df.csv")

# %%
data=pd.read_csv('df.csv')

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081         NaN  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     37.82
# 20636  2.5568      18.0  6.114035   1.315789       356.0       NaN     37.82
# 20637  1.7000      17.0  5.205543   1.120092      1007.0       NaN     37.82
# 20638  1.8672      18.0  5.329513   1.171920       741.0       NaN     37.82
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     37.82
#
#        Longitude  MedHouseVal
# ...

# %%
data.isnull().sum()
# Out:
# MedInc          6
# HouseAge        6
# AveRooms       12
# AveBedrms      10
# Population      7
# AveOccup        6
# Latitude        2
# Longitude       5
# MedHouseVal     4
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sbs

# %%
data.skew()
# Out:
# MedInc          1.646481
# HouseAge        0.060076
# AveRooms       20.695153
# AveBedrms      31.310779
# Population      4.936486
# AveOccup       97.625521
# Latitude       14.347627
# Longitude      -0.298352
# MedHouseVal     0.977641
# dtype: float64

# %%
for column in df.columns:
    plt.figure(figsize=(8, 5))
    plt.hist(data[column], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
min(df['AveRooms']),max(df['AveRooms'])
# Out:
# (0.846153846, 141.9090909)

# %%
mean_values = data.mean()
std_dev_values = data.std()
mean_values,std_dev_values
# Out:
# (MedInc            3.871153
#  HouseAge         28.638606
#  AveRooms          5.429214
#  AveBedrms         1.096704
#  Population     1425.587699
#  AveOccup          3.070823
#  Latitude         37.820045
#  Longitude      -119.569118
#  MedHouseVal       2.068800
#  dtype: float64,
#  MedInc            1.899873
#  HouseAge         12.585007
#  AveRooms          2.474753
#  AveBedrms         0.474018
#  Population     1132.511084
#  AveOccup         10.387552
#  Latitude          0.001456
#  Longitude         2.003412
#  MedHouseVal       1.153934
#  dtype: float64)

# %%
mean_value = data.mean()
std_dev_value = data.std()
z_values = (data - mean_values) / std_dev_value
threshold = 3
outliers = data[(abs(z_values) < threshold).all(axis=1)]
outliers
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 47     1.7348      43.0  3.980237   1.233202       558.0  2.205534     37.82
# 48     0.9506      40.0  3.900000   1.218750       423.0  2.643750     37.82
# 49     1.7750      40.0  2.687500   1.065341       700.0  1.988636     37.82
# 50     0.9218      21.0  2.045662   1.034247       735.0  1.678082     37.82
# 51     1.5045      43.0  4.589681   1.120393      1061.0  2.606880     37.82
# ...       ...       ...       ...        ...         ...       ...       ...
# 20628  2.5952      19.0  5.238462   1.079487      1018.0  2.610256     37.82
# 20630  3.5673      11.0  5.932584   1.134831      1257.0  2.824719     37.82
# 20632  3.1250      15.0  6.023377   1.080519      1047.0  2.719481     37.82
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     37.82
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     37.82
#
#        Longitude  MedHouseVal
# ...

# %%
for column in outliers.columns:
    plt.figure(figsize=(8, 5))
    plt.hist(data[column], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
outliers.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
sbs.boxplot(data)
# Out:
# <Axes: >

# %%
sbs.boxplot(outliers,orient='h')
# Out:
# <Axes: >

# %%
sbs.boxplot(data,orient='h')
# Out:
# <Axes: >

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081         NaN  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     37.82
# 20636  2.5568      18.0  6.114035   1.315789       356.0       NaN     37.82
# 20637  1.7000      17.0  5.205543   1.120092      1007.0       NaN     37.82
# 20638  1.8672      18.0  5.329513   1.171920       741.0       NaN     37.82
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     37.82
#
#        Longitude  MedHouseVal
# ...

# %%
# Calculate quartiles using describe() method
quartiles = data.describe().loc[['25%', '75%']]

# Calculate IQR (Interquartile Range)
IQR = quartiles.diff().iloc[1]

quartiles
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 25%  2.564075      18.0  4.440584    1.00609       787.0  2.430134     37.82
# 75%  4.743700      37.0  6.052381    1.09952      1725.0  3.282279     37.82
#
#      Longitude  MedHouseVal
# 25%    -121.80      1.19700
# 75%    -118.01      2.64825

# %%
IQR
# Out:
# MedInc           2.179625
# HouseAge        19.000000
# AveRooms         1.611797
# AveBedrms        0.093430
# Population     938.000000
# AveOccup         0.852145
# Latitude         0.000000
# Longitude        3.790000
# MedHouseVal      1.451250
# Name: 75%, dtype: float64

# %%
Q1=data.describe().loc['25%']
Q1
# Out:
# MedInc           2.564075
# HouseAge        18.000000
# AveRooms         4.440584
# AveBedrms        1.006090
# Population     787.000000
# AveOccup         2.430134
# Latitude        37.820000
# Longitude     -121.800000
# MedHouseVal      1.197000
# Name: 25%, dtype: float64

# %%
Q3=data.describe().loc['75%']
Q3
# Out:
# MedInc            4.743700
# HouseAge         37.000000
# AveRooms          6.052381
# AveBedrms         1.099520
# Population     1725.000000
# AveOccup          3.282279
# Latitude         37.820000
# Longitude      -118.010000
# MedHouseVal       2.648250
# Name: 75%, dtype: float64

# %%
# Calculate lower and upper bounds for outlier detection
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data based on the interquartile range (IQR)
clean_data = data[(data >= lower_bound) & (data <= upper_bound)].dropna()

print(clean_data)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 47     1.7348      43.0  3.980237   1.233202       558.0  2.205534     37.82
# 48     0.9506      40.0  3.900000   1.218750       423.0  2.643750     37.82
# 49     1.7750      40.0  2.687500   1.065341       700.0  1.988636     37.82
# 50     0.9218      21.0  2.045662   1.034247       735.0  1.678082     37.82
# 51     1.5045      43.0  4.589681   1.120393      1061.0  2.606880     37.82
# ...       ...       ...       ...        ...         ...       ...       ...
# 20628  2.5952      19.0  5.238462   1.079487      1018.0  2.610256     37.82
# 20630  3.5673      11.0  5.932584   1.134831      1257.0  2.824719     37.82
# 20632  3.1250      15.0  6.023377   1.080519      1047.0  2.719481     37.82
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     37.82
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     37.82
#
#        Longitude  MedHouseVal
# ...

# %%
sbs.boxplot(clean_data,orient='h')
# Out:
# <Axes: >

# %%
sbs.boxplot(outliers,orient='h')
# Out:
# <Axes: >

# %%
cols_to_drop=['Population','Longitude','HouseAge']
clean_data=clean_data.drop(cols_to_drop,axis=1)
outliers=outliers.drop(cols_to_drop,axis=1)

# %%
clean_data.reset_index(drop=True, inplace=True)
sbs.boxplot(clean_data,orient='h')
# Out:
# <Axes: >

# %%
sbs.boxplot(outliers,orient='h')
# Out:
# <Axes: >

# %%
 data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081         NaN  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     37.82
# 20636  2.5568      18.0  6.114035   1.315789       356.0       NaN     37.82
# 20637  1.7000      17.0  5.205543   1.120092      1007.0       NaN     37.82
# 20638  1.8672      18.0  5.329513   1.171920       741.0       NaN     37.82
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     37.82
#
#        Longitude  MedHouseVal
# ...

# %%
x=data.drop('MedHouseVal',axis=1)
y=data['MedHouseVal']

# %%
x.shape, y.shape
# Out:
# ((20640, 8), (20640,))

# %%
for column in x.columns:
    plt.scatter(x[column],y)
    plt.show()

# %%
x=clean_data.drop('MedHouseVal',axis=1)
y=clean_data['MedHouseVal']
for column in x.columns:
    plt.scatter(x[column],y)
    plt.plot(np.unique(x[column]), np.poly1d(np.polyfit(x[column], y, 1))
         (np.unique(x[column])), color='red')
    plt.show()

# %%
import sklearn
for column in x.columns:
    print(y.corr(x[column]))
# Out:
# 0.631622723723235
# 0.08788323398930618
# 0.2591909346076849
# -0.09710975808300543
# -0.008184538592791576
# -0.27604676117526283
# nan
# -0.04463266391535965

# %%
from sklearn.ensemble import RandomForestRegressor

X, Y = x,y
model = RandomForestRegressor( random_state=42)
model.fit(X, Y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
feature_importances = model.feature_importances_

# Sort feature importances in descending order
indices = np.argsort(feature_importances)[::-1]
feature_names=X.columns
# Print feature ranking
print("Feature ranking:")
for f in range(len(indices)):
    print("%d. feature %s (%f)" % (f + 1, feature_names[indices[f]], feature_importances[indices[f]]))

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X.shape[1]), feature_importances[indices],
        color="b", align="center")
plt.xticks(range(X.shape[1]), feature_names[indices], rotation=90)
plt.xlabel("Feature Name")
plt.ylabel("Feature Importance")
plt.show()
# Out:
# Feature ranking:
# 1. feature MedInc (0.458845)
# 2. feature AveOccup (0.154500)
# 3. feature Longitude (0.122596)
# 4. feature AveRooms (0.089182)
# 5. feature HouseAge (0.074108)
# 6. feature Population (0.051194)
# 7. feature AveBedrms (0.049577)
# 8. feature Latitude (0.000000)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X,Y)

# %%
reg.score(X,Y)
# Out:
# 0.5676111167328526

# %%
reg.coef_
# Out:
# array([ 6.02549191e-01,  1.66670248e-02, -2.91041879e-01,  1.80411018e+00,
#         1.07215118e-04, -3.47349883e-01,  0.00000000e+00, -4.53781693e-03])

# %%
predictions = reg.predict(X)

# Plot actual vs predicted values
plt.scatter(Y, predictions)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.plot([min(Y), max(Y)], [min(Y), max(Y)], color='red', label='Line of Best Fit')

plt.show()
